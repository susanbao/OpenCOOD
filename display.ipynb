# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

import open3d
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
def DisplayImage(file):
    lena = mpimg.imread(file)
    plt.imshow(lena)
    plt.axis('off')
    plt.show()

# %%
DisplayImage('opv2v_data_dumping/train/2021_08_16_22_26_54/641/000069_camera0.png')
DisplayImage('opv2v_data_dumping/train/2021_08_16_22_26_54/641/000069_camera1.png')
DisplayImage('opv2v_data_dumping/train/2021_08_16_22_26_54/641/000069_camera2.png')
DisplayImage('opv2v_data_dumping/train/2021_08_16_22_26_54/641/000069_camera3.png')

# %%
DisplayImage('opv2v_data_dumping/train/2021_08_16_22_26_54/641/000071_camera0.png')
DisplayImage('opv2v_data_dumping/train/2021_08_16_22_26_54/641/000071_camera1.png')
DisplayImage('opv2v_data_dumping/train/2021_08_16_22_26_54/641/000071_camera2.png')
DisplayImage('opv2v_data_dumping/train/2021_08_16_22_26_54/641/000071_camera3.png')

# %%
DisplayImage('opv2v_data_dumping/train/2021_08_16_22_26_54/650/000069_camera0.png')
DisplayImage('opv2v_data_dumping/train/2021_08_16_22_26_54/650/000069_camera1.png')
DisplayImage('opv2v_data_dumping/train/2021_08_16_22_26_54/650/000069_camera2.png')
DisplayImage('opv2v_data_dumping/train/2021_08_16_22_26_54/650/000069_camera3.png')

# %%
DisplayImage('opv2v_data_dumping/train/2021_08_16_22_26_54/659/000069_camera0.png')
DisplayImage('opv2v_data_dumping/train/2021_08_16_22_26_54/659/000069_camera1.png')
DisplayImage('opv2v_data_dumping/train/2021_08_16_22_26_54/659/000069_camera2.png')
DisplayImage('opv2v_data_dumping/train/2021_08_16_22_26_54/659/000069_camera3.png')

# %%
pcd = open3d.io.read_point_cloud('opv2v_data_dumping/train/2021_08_16_22_26_54/641/000069.pcd')
print(pcd)
print(np.asarray(pcd.points))
open3d.visualization.draw_geometries([pcd])
# Out:
# PointCloud with 57425 points.
# [[-1.18134934e+02 -9.51806450e+00  4.13873720e+00]
#  [-1.18096268e+02 -1.02504129e+01  4.13952160e+00]
#  [-1.18623375e+02 -1.32596044e+01  4.16821957e+00]
#  ...
#  [-1.63670456e+00  3.03602926e-02 -7.63337970e-01]
#  [-1.64471853e+00  2.03320216e-02 -7.67001986e-01]
#  [-1.64977622e+00  1.01845218e-02 -7.69316614e-01]]
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] [DrawGeometries] Failed creating OpenGL window.
