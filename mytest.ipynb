# %% [markdown]
# ## Testing

# %% [markdown]
# ## Pointpillar

# %% [markdown]
# ### pointpillar with intermediate fusion, 0.5: 0.908, 0.7: 0.815 in the paper for test dataset

# %%
# !python opencood/tools/inference.py --model_dir checkpoint/pointpillar_attentive_fusion --fusion_method 'intermediate'
# Out:
# Dataset Building
# Creating Model
# cuda
# Loading Model from checkpoint
# 0
# /home/sas20048/anaconda/envs/opencood/lib/python3.7/site-packages/torch/nn/functional.py:1944: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# 100
# 200
# 300
# 400
# 500
# The Average Precision at IOU 0.3 is 0.872, The Average Precision at IOU 0.5 is 0.854, The Average Precision at IOU 0.7 is 0.736

# %%
# !python opencood/tools/inference.py --model_dir checkpoint/pointpillar_attentive_fusion --fusion_method 'intermediate' --save_vis
# Out:
# Dataset Building
# Creating Model
# cuda
# Loading Model from checkpoint
# 0
# /home/sas20048/anaconda/envs/opencood/lib/python3.7/site-packages/torch/nn/functional.py:1944: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# [Open3D WARNING] GLFW Error: X11: The DISPLAY environment variable is missing
# [Open3D WARNING] Failed to initialize GLFW
# [Open3D WARNING] GLFW Error: The GLFW library is not initialized
# [Open3D WARNING] GLFW Error: The GLFW library is not initialized
# [Open3D WARNING] GLFW Error: The GLFW library is not initialized
# [Open3D WARNING] GLFW Error: The GLFW library is not initialized
# [Open3D WARNING] GLFW Error: The GLFW library is not initialized
# [Open3D WARNING] GLFW Error: The GLFW library is not initialized
# [Open3D WARNING] GLFW Error: The GLFW library is not initialized
# [Open3D WARNING] GLFW Error: The GLFW library is not initialized
# ...

# %% [markdown]
# ### pointpillar with late fusion, 0.5: 0.799, 0.7: 0.668 in the paper for Culver dataset

# %%
# !python opencood/tools/inference.py --model_dir checkpoint/pointpillar_late_fusion --fusion_method 'late'
# Out:
# Dataset Building
# Creating Model
# cuda
# Loading Model from checkpoint
# resuming by loading epoch 30
# 0
# /home/sas20048/anaconda/envs/opencood/lib/python3.7/site-packages/torch/nn/functional.py:1944: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100

# %%
# !python opencood/tools/inference.py --model_dir checkpoint/pointpillar_early_fusion --fusion_method 'early'
# Out:
# Dataset Building
# Creating Model
# cuda
# Loading Model from checkpoint
# 0
# /home/sas20048/anaconda/envs/opencood/lib/python3.7/site-packages/torch/nn/functional.py:1944: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# The Average Precision at IOU 0.3 is 0.902, The Average Precision at IOU 0.5 is 0.892, The Average Precision at IOU 0.7 is 0.801

# %% [markdown]
# ## Voxelnet

# %% [markdown]
# ### voxelnet with early fusion, 0.5: 0.852, 0.7: 0.758 in the paper for test dataset

# %%
# !python opencood/tools/inference.py --model_dir checkpoint/voxelnet_early_fusion --fusion_method 'early'
# Out:
# Dataset Building
# Creating Model
# cuda
# Loading Model from checkpoint
# 0
# /home/sas20048/anaconda/envs/opencood/lib/python3.7/site-packages/torch/nn/functional.py:1944: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# 100
# 200
# 300
# 400
# 500
# The Average Precision at IOU 0.3 is 0.832, The Average Precision at IOU 0.5 is 0.816, The Average Precision at IOU 0.7 is 0.677

# %% [markdown]
# ### voxelnet with intermediate fusion, 0.5: 0.906, 0.7: 0.864 in the paper for test dataset

# %%
# !python opencood/tools/inference.py --model_dir checkpoint/voxelnet_attentive_fusion/voxelnet_attentive_fusion --fusion_method 'intermediate'
# Out:
# Dataset Building
# Creating Model
# cuda
# Loading Model from checkpoint
# 0
# /home/sas20048/anaconda/envs/opencood/lib/python3.7/site-packages/torch/nn/functional.py:1944: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# 100
# 200
# 300
# 400
# 500
# The Average Precision at IOU 0.3 is 0.864, The Average Precision at IOU 0.5 is 0.854, The Average Precision at IOU 0.7 is 0.775

# %% [markdown]
# ### SECOND

# %%
# !python opencood/tools/inference.py --model_dir checkpoint/second_early_fusion --fusion_method 'early'
# Out:
# Dataset Building
# Creating Model
# cuda
# Loading Model from checkpoint
# 0
# Traceback (most recent call last):
#   File "opencood/tools/inference.py", line 136, in <module>
#     main()
#   File "opencood/tools/inference.py", line 79, in main
#     opencood_dataset)
#   File "/home/sas20048/code/OpenCOOD/opencood/tools/inference_utils.py", line 59, in inference_early_fusion
#     output_dict['ego'] = model(cav_content)
#   File "/home/sas20048/anaconda/envs/opencood/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1110, in _call_impl
#     return forward_call(*input, **kwargs)
#   File "/home/sas20048/code/OpenCOOD/opencood/models/second.py", line 42, in forward
#     batch_dict = self.backbone_3d(batch_dict)
#   File "/home/sas20048/anaconda/envs/opencood/lib/python3.7/site-packages/torch/nn/modules/module.py", line 1110, in _call_impl
#     return forward_call(*input, **kwargs)
# ...

# %% [markdown]
# https://githubmemory.com/repo/xinge008/Cylinder3D/issues/4
#
# https://github.com/traveller59/spconv/issues/58
#
# We need to install CUDA 10.2 to solve this problem. It only influences SECOND. But it is complex. So currently, I won't solve it.

# %% [markdown]
# # Training

# %%
# !python opencood/tools/inference.py --model_dir opencood/logs/point_pillar_intermediate_fusion_2022_03_15_22_13_46 --fusion_method 'intermediate'
# Out:
# Dataset Building
# Creating Model
# cuda
# Loading Model from checkpoint
# resuming by loading epoch 15
# 0
# /home/sas20048/anaconda/envs/opencood/lib/python3.7/site-packages/torch/nn/functional.py:1944: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# 100
# 200
# 300
# 400
# 500
# The Average Precision at IOU 0.3 is 0.892, The Average Precision at IOU 0.5 is 0.873, The Average Precision at IOU 0.7 is 0.749

# %%
# !python opencood/tools/inference.py --model_dir opencood/logs/point_pillar_late_fusion_2022_03_16_17_16_31 --fusion_method 'late'
# Out:
# Dataset Building
# Creating Model
# cuda
# Loading Model from checkpoint
# resuming by loading epoch 15
# 0
# /home/sas20048/anaconda/envs/opencood/lib/python3.7/site-packages/torch/nn/functional.py:1944: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# 100
# 200
# 300
# 400
# 500
# The Average Precision at IOU 0.3 is 0.827, The Average Precision at IOU 0.5 is 0.808, The Average Precision at IOU 0.7 is 0.682

# %%
# !python opencood/tools/inference.py --model_dir opencood/logs/point_pillar_early_fusion_2022_03_17_11_12_05 --fusion_method 'early'
# Out:
# Dataset Building
# Creating Model
# cuda
# Loading Model from checkpoint
# resuming by loading epoch 15
# 0
# /home/sas20048/anaconda/envs/opencood/lib/python3.7/site-packages/torch/nn/functional.py:1944: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# 100
# 200
# 300
# 400
# 500
# The Average Precision at IOU 0.3 is 0.859, The Average Precision at IOU 0.5 is 0.843, The Average Precision at IOU 0.7 is 0.729

# %%
# !python opencood/tools/train.py --hypes_yaml opencood/hypes_yaml/point_pillar_late_fusion.yaml
# Out:
# Dataset Building
# Creating Model
# cuda
# Training start
# learning rate 0.002000
# [epoch 0][1/3382], || Loss: 391.5066 || Conf Loss: 385.2286 || Loc Loss: 6.2779
# [epoch 0][2/3382], || Loss: 151.4467 || Conf Loss: 147.0018 || Loc Loss: 4.4450
# [epoch 0][3/3382], || Loss: 155.6270 || Conf Loss: 151.4530 || Loc Loss: 4.1741
# [epoch 0][4/3382], || Loss: 145.3653 || Conf Loss: 141.2438 || Loc Loss: 4.1215
# [epoch 0][5/3382], || Loss: 26.6613 || Conf Loss: 23.1896 || Loc Loss: 3.4717
# [epoch 0][6/3382], || Loss: 19.3662 || Conf Loss: 16.4295 || Loc Loss: 2.9367
# [epoch 0][7/3382], || Loss: 49.7139 || Conf Loss: 44.5746 || Loc Loss: 5.1393
# [epoch 0][8/3382], || Loss: 9.7489 || Conf Loss: 5.5580 || Loc Loss: 4.1908
# [epoch 0][9/3382], || Loss: 6.8754 || Conf Loss: 3.2096 || Loc Loss: 3.6659
# [epoch 0][10/3382], || Loss: 6.3227 || Conf Loss: 3.3278 || Loc Loss: 2.9949
# [epoch 0][11/3382], || Loss: 3.6981 || Conf Loss: 1.6680 || Loc Loss: 2.0301
# ...
